# %%
import numpy as np
from lib import gr
import matplotlib.pyplot as plt
import lib.mesurements
import lib.haar_wawelet_method.haar as haar
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-aacdda6b7b6b> in <module>()
#       2
#       3 import matplotlib.pyplot as plt
# ----> 4 import lib.mesurements
#       5 import lib.haar_wawelet_method.haar as haar
#       6 get_ipython().magic('matplotlib inline')
#
# ModuleNotFoundError: No module named 'lib'

# %%
def draw_plot(z):
    size = z.shape[0]
    x,y = np.meshgrid(range(0,size),range(0,size))
    from mpl_toolkits.mplot3d import Axes3D
    fig = plt.figure(figsize=(30,30))
    ax = fig.gca(projection='3d')
    ax.plot_wireframe(x, y, z)
    ax.set_zlim(0, 2)
    ax.set_xlim(0,size)
    ax.set_ylim(0,size)
    from matplotlib.ticker import MultipleLocator, FormatStrFormatter
    majorLocator = MultipleLocator(2)
    majorFormatter = FormatStrFormatter('%d')
    ax.xaxis.set_major_locator(majorLocator)
    ax.xaxis.set_major_formatter(majorFormatter)
    ax.yaxis.set_major_locator(majorLocator)
    ax.yaxis.set_major_formatter(majorFormatter)

# %%
from ReportTools.WaweletMethodFrequencyCharackteristickExperiment import WaweletMethodFrequencyCharackteristickExperiment

# %%
ex = WaweletMethodFrequencyCharackteristickExperiment("256*256grid_with_noise", grid_degree=7)
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-4-280795f6f921> in <module>()
# ----> 1 ex = WaweletMethodFrequencyCharackteristickExperiment("256*256grid_with_noise", grid_degree=7)
#
# /home/satbek/Course-work-sem7/src/ReportTools/WaweletMethodFrequencyCharackteristickExperiment.py in __init__(self, name, reported, grid_degree)
#      12
#      13     def __init__(self, name, reported=True, grid_degree=7):
# ---> 14         super().__init__(name, reported)
#      15         x, y = data.get_plane(-np.pi, np.pi, -np.pi, np.pi, grid_degree)
#      16         self._plane = {'x': x, 'y': y}
#
# /home/satbek/Course-work-sem7/src/ReportTools/Experiment.py in __init__(self, name, reported)
#      20         """
#      21         self.name = name
# ---> 22         self.description = input("Write description to experiment: ")
#      23         self.datetime = datetime.today()
#      24         self.report = None
#
# /home/satbek/python/anacondas/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     698         if not self._allow_stdin:
#     699             raise StdinNotImplementedError(
# --> 700                 "raw_input was called, but this frontend does not support input requests."
#     701             )
#     702         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
ex.execute(noised=True, photons=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-db3c9cb5fb04> in <module>()
# ----> 1 ex.execute(noised=True, photons=0.5)
#
# NameError: name 'ex' is not defined

# %%
draw_plot(ex.Result)

# %%
def compare_ideal(i,j,M, noised = False, photons = 1):
    x,y = data.get_plane(-np.pi, np.pi,-np.pi,np.pi,M)
    im = my_exp(x,y,i,j)
    grad_X, grad_Y = i * x * 1j * my_exp(x,y,i,j), j * y * 1j * my_exp(x,y,i,j)
    if (noised):
        #как зашумлять комплексные числа?
        grad_X = poisson_noised(grad_X.real, photons) + 1j*poisson_noised(grad_X.imag, photons)
        grad_Y = poisson_noised(grad_Y.real, photons) + 1j*poisson_noised(grad_Y.imag, photons)
    LH, HL, HH = haar.analyze(grad_X, grad_Y, grad_X, grad_Y)
    res = haar.syntesis({0:np.array([[np.mean(im)*2**M]])}, LH, HL, HH,M)
    return np.abs(np.fft.fft2(im)[j,i])/np.abs(np.fft.fft2(res[M])[j,i])

# %%
def calc_z_ideal (M, noised = False, photons = 1):
    size = 2**M
    z = np.zeros(size**2).reshape(size,size)
    for i in range (size):
        print(i)
        if (i*10 <= size):
            for j in range(size):
                print(j)
                if (j*10 <= size):
                    z[i,j] = compare_ideal(i,j,M, noised,photons)
                else:
                    break
        else :
            continue
    return z

# %%
z = calc_z_ideal(7, False)
# Out:
# 0
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-eb1f03550929> in <module>()
# ----> 1 z = calc_z_ideal(7, False)
#
# <ipython-input-13-84a6195778af> in calc_z_ideal(M, noised, photons)
#       8                 print(j)
#       9                 if (j*10 <= size):
# ---> 10                     z[i,j] = compare_ideal(i,j,M, noised,photons)
#      11                 else:
#      12                     break
#
# <ipython-input-12-84760396d70e> in compare_ideal(i, j, M, noised, photons)
#       1 def compare_ideal(i,j,M, noised = False, photons = 1):
#       2     x,y = data.get_plane(-np.pi, np.pi,-np.pi,np.pi,M)
# ----> 3     im = my_exp(x,y,i,j)
#       4     grad_X, grad_Y = i * x * 1j * my_exp(x,y,i,j), j * y * 1j * my_exp(x,y,i,j)
#       5     if (noised):
#
# NameError: name 'my_exp' is not defined

# %%
draw_plot(z[1:13,1:13])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-577fbfdb348b> in <module>()
# ----> 1 draw_plot(z[1:13,1:13])
#
# NameError: name 'z' is not defined
